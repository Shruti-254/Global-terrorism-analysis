# %% [markdown]
# <a href="https://colab.research.google.com/github/shrutika-kawade/Global-terrorism-analysis/blob/main/Global_Terrorism_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.</b>
#
# # <b> Explore and analyze the data to discover key findings pertaining to terrorist activities. </b>

# %%
#Import package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#Mount Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
path = '/content/drive/MyDrive/'
ds_gta = pd.read_csv(path + 'Global Terrorism Data.csv', encoding='latin-1')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
ds_gta
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
ds_gta.shape
# Out:
# (181691, 135)

# %%
ds_gta.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
ds_gta.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
ds_gta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
ds_gta.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
ds_gta.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
ds_gta.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
ds_gta.shape[0]
# Out:
# 181691

# %%
null_val=ds_gta.isnull().sum()/ds_gta.shape[0]*100  #calculating percentage of null values in each columns
null_val
# Out:
# eventid        0.000000
# iyear          0.000000
# imonth         0.000000
# iday           0.000000
# approxdate    94.914993
#                 ...
# INT_LOG        0.000000
# INT_IDEO       0.000000
# INT_MISC       0.000000
# INT_ANY        0.000000
# related       86.219461
# Length: 135, dtype: float64

# %%
drop_columns=null_val [null_val >10].keys() #stroring the name of coulmns which is having more then 10% of null values
drop_columns
# Out:
# Index(['approxdate', 'resolution', 'location', 'summary', 'alternative',
#        'alternative_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3',
#        'attacktype3_txt', 'corp1', 'targtype2', 'targtype2_txt',
#        'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2',
#        'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3',
#        'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt',
#        'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive',
#        'guncertain2', 'guncertain3', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt',
#        'claim3', 'claimmode3', 'claimmode3_txt', 'compclaim', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
# ...

# %%
drop_data = ds_gta.drop(columns=drop_columns)
drop_data
# Out:
#              eventid  iyear  imonth  iday  extended  country  \
# 0       197000000001   1970       7     2         0       58
# 1       197000000002   1970       0     0         0      130
# 2       197001000001   1970       1     0         0      160
# 3       197001000002   1970       1     0         0       78
# 4       197001000003   1970       1     0         0      101
# ...              ...    ...     ...   ...       ...      ...
# 181686  201712310022   2017      12    31         0      182
# 181687  201712310029   2017      12    31         0      200
# 181688  201712310030   2017      12    31         0      160
# 181689  201712310031   2017      12    31         0       92
# 181690  201712310032   2017      12    31         0      160
#
#                country_txt  region                   region_txt  \
# 0       Dominican Republic       2  Central America & Caribbean
# 1                   Mexico       1                North America
# ...

# %%
drop_data.shape
# Out:
# (181691, 45)

# %%
sns.heatmap(drop_data.isnull())

# %%
drop_data=drop_data.dropna()

# %%
sns.heatmap(drop_data.isnull())

# %%
drop_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149355 entries, 1 to 181689
# Data columns (total 45 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   eventid           149355 non-null  int64
#  1   iyear             149355 non-null  int64
#  2   imonth            149355 non-null  int64
#  3   iday              149355 non-null  int64
#  4   extended          149355 non-null  int64
#  5   country           149355 non-null  int64
#  6   country_txt       149355 non-null  object
#  7   region            149355 non-null  int64
#  8   region_txt        149355 non-null  object
#  9   provstate         149355 non-null  object
#  10  city              149355 non-null  object
#  11  latitude          149355 non-null  float64
#  12  longitude         149355 non-null  float64
#  13  specificity       149355 non-null  float64
#  14  vicinity          149355 non-null  int64
#  15  crit1             149355 non-null  int64
# ...

# %%
data_gta = drop_data.drop(columns=['extended','region','specificity','vicinity','crit1','crit2','crit3','doubtterr','multiple','attacktype1','targtype1','targsubtype1','natlty1','natlty1_txt','guncertain1','individual','weaptype1','property','ishostkid','dbsource','INT_LOG','INT_IDEO','INT_MISC','INT_ANY'])

# %%
data_gta.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country', 'country_txt',
#        'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'success',
#        'suicide', 'attacktype1_txt', 'targtype1_txt', 'targsubtype1_txt',
#        'target1', 'gname', 'weaptype1_txt', 'nkill', 'nwound'],
#       dtype='object')

# %%
data_gta.shape
# Out:
# (149355, 21)

# %%
data_gta = data_gta.rename(columns={
    'eventid':'Event_id',
    'iyear':'Year',
    'imonth':'Month',
    'iday':'Day',
    'country':'Country_id',
    'country_txt':'Country',
    'region_txt':'Region',
    'provstate':'State',
    'city':'City',
    'attacktype1_txt':'Type_of_attack',
    'targtype1_txt':'Targeted_area',
    'targsubtype1_txt':'Targeted_place',
    'target1':'Main_target',
    'gname':'Group_name',
    'weaptype1_txt':'Weapon_type',
    'nkill':'Killed',
    'nwound':'Wounded'
    
})

# %%
data_gta.columns
# Out:
# Index(['Event_id', 'Year', 'Month', 'Day', 'Country_id', 'Country', 'Region',
#        'State', 'City', 'latitude', 'longitude', 'success', 'suicide',
#        'Type_of_attack', 'Targeted_area', 'Targeted_place', 'Main_target',
#        'Group_name', 'Weapon_type', 'Killed', 'Wounded'],
#       dtype='object')

# %%
print('Country with most attacks: ',data_gta['Country'].value_counts().idxmax())
Country_with_most_attacks=data_gta['Country'].value_counts().idxmax()
data_gta[data_gta['Country']==Country_with_most_attacks]
print('City with most attacks: ',data_gta['City'].value_counts().idxmax())
City_with_most_attacks=data_gta['City'].value_counts().idxmax()

print("Region with the most attacks:",data_gta['Region'].value_counts().idxmax())
Region_with_the_most_attacks=data_gta['Region'].value_counts().idxmax()

print("Year with the most attacks:",data_gta['Year'].value_counts().idxmax())
Year_with_the_most_attacks=data_gta['Year'].value_counts().idxmax()
    
print("Month with the most attacks:",data_gta['Month'].value_counts().idxmax())
Month_with_the_most_attacks=data_gta['Month'].value_counts().idxmax()

print("Group with the most attacks:",data_gta['Group_name'].value_counts().index[1])
Group_with_the_most_attacks=data_gta['Group_name'].value_counts().index[1]

print("Most Attack Types:",data_gta['Type_of_attack'].value_counts().idxmax())
Most_Attack_Types=data_gta['Type_of_attack'].value_counts().idxmax()
# Out:
# Country with most attacks:  Iraq
# City with most attacks:  Baghdad
# Region with the most attacks: Middle East & North Africa
# Year with the most attacks: 2014
# Month with the most attacks: 5
# Group with the most attacks: Taliban
# Most Attack Types: Bombing/Explosion

# %%
# attacks in every year
x_year = data_gta['Year'].unique()
y_year = data_gta['Year'].value_counts().sort_index()
plt.figure(figsize=(15,10))
plt.bar(x_year, y_year)
plt.title('NUMBER OF KILL PER YEAR')
plt.xlabel('Year')
plt.ylabel('Count of kill')
plt.show()

# %%
#Terrorist group names and number of killed 
group_killed= data_gta[['Group_name','Killed']].groupby(['Group_name'],axis=0).sum().sort_values('Killed', ascending=False).head(15)
group_killed.reset_index()
# Out:
#                                           Group_name   Killed
# 0                                            Unknown  95399.0
# 1        Islamic State of Iraq and the Levant (ISIL)  27174.0
# 2                                            Taliban  25785.0
# 3                                         Boko Haram  10732.0
# 4            Liberation Tigers of Tamil Eelam (LTTE)   9393.0
# 5                                  Shining Path (SL)   9315.0
# 6                                         Al-Shabaab   6836.0
# 7   Farabundo Marti National Liberation Front (FMLN)   6801.0
# 8                    Tehrik-i-Taliban Pakistan (TTP)   5580.0
# 9      Revolutionary Armed Forces of Colombia (FARC)   4380.0
# 10                    Kurdistan Workers' Party (PKK)   4093.0
# 11                                  Al-Qaida in Iraq   3984.0
# 12                 Nicaraguan Democratic Force (FDN)   3883.0
# 13                                          Al-Qaida   3818.0
# ...

# %%
plt.subplots(figsize=(12,6))
sns.barplot(group_killed.index, group_killed.Killed.values,palette="crest")
plt.title('Number of People Killed by each terroris group')
plt.xlabel('Terrorist Groups')
plt.ylabel('Number of people killed')
plt.xticks(rotation= 75)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data_gta[data_gta['Killed']==data_gta.Killed.max()]
# Out:
#            Event_id  Year  Month  Day  Country_id        Country  \
# 73126  200109110004  2001      9   11         217  United States
#
#               Region     State           City   latitude  ...  success  \
# 73126  North America  New York  New York City  40.697132  ...        1
#
#        suicide  Type_of_attack                Targeted_area  \
# 73126        1       Hijacking  Private Citizens & Property
#
#                      Targeted_place  \
# 73126  Unnamed Civilian/Unspecified
#
#                                              Main_target Group_name  \
# 73126  Passengers and crew members on American Airlin...   Al-Qaida
#
#                                              Weapon_type  Killed  Wounded
# 73126  Vehicle (not to include vehicle-borne explosiv...  1384.0   8190.0
#
# [1 rows x 21 columns]

# %%
g_country=data_gta.groupby('Country')
max_number_of_kill_in_each_country=g_country.max('Killed')
max_number_of_kill_in_each_country
# Out:
#                  Event_id  Year  Month  Day  Country_id   latitude  longitude  \
# Country
# Afghanistan  201712310020  2017     12   31           4  37.769393  71.584167
# Albania      201710110028  2017     12   29           5  42.399981  20.421944
# Algeria      201709220009  2017     12   31           6  37.068190   9.556767
# Angola       201708250057  2017     12   31           8  -4.446342  23.016835
# Argentina    201708020032  2017     12   31          11 -23.276090 -55.900812
# ...                   ...   ...    ...  ...         ...        ...        ...
# Yemen        201712290016  2017     12   31         228  17.489364  50.581538
# Yugoslavia   200206130002  2002     12   31         235  46.100278  22.143022
# Zaire        199705120008  1997     12   31         604   1.010278  29.593583
# Zambia       201707090040  2017     12   31         230 -12.166857  32.902500
# Zimbabwe     201707180043  2017     12   31         231 -16.646518  32.800000
#
# ...

# %%
max_number_of_kill_in_each_country=max_number_of_kill_in_each_country[max_number_of_kill_in_each_country['Killed']>300]
max_number_of_kill_in_each_country=max_number_of_kill_in_each_country.reset_index()
max_number_of_kill_in_each_country
# Out:
#           Country      Event_id  Year  Month  Day  Country_id   latitude  \
# 0         Burundi  201712040036  2017     12   31          34  -2.525794
# 1          Canada  201709300013  2017     12   31          38  55.754211
# 2           Egypt  201712290003  2017     12   31          60  31.441411
# 3            Iran  201707150027  2017     12   31          94  39.391389
# 4            Iraq  201712310012  2017     12   31          95  37.230226
# 5      Mozambique  201712170030  2017     12   31         137 -10.596982
# 6           Nepal  201712220016  2017     12   31         141  29.916806
# 7          Russia  201712280028  2017     12   31         167  74.633553
# 8          Rwanda  201706200037  2017     12   31         168  -1.448369
# 9         Somalia  201712310022  2017     12   31         182  11.472014
# 10  United States  201712220023  2017     12   31         217  64.837778
#
#      longitude  success  suicide  Killed  Wounded
# ...

# %%
plt.figure(figsize=(35,15))
plt.xlabel('COUNTRY')
plt.ylabel('NUMBER OF KILL')
plt.title('Max_Number_Of_Kill_In_Each_Country Which Is Greater Then 200')
plt.bar(max_number_of_kill_in_each_country.Country,max_number_of_kill_in_each_country.Killed,label='Number of kill')
plt.legend()
for i in range(len(max_number_of_kill_in_each_country['Country'])):
        plt.text(max_number_of_kill_in_each_country['Country'][i],max_number_of_kill_in_each_country['Killed'][i],max_number_of_kill_in_each_country['Killed'][i],fontsize=25)

# %%
group_gname=data_gta.groupby('Group_name')
Al_Qaida=group_gname.get_group('Al-Qaida')
Al_Qaida
# Out:
#             Event_id  Year  Month  Day  Country_id   Country  \
# 54691   199212290002  1992     12   29         228     Yemen
# 54692   199212290003  1992     12   29         228     Yemen
# 68071   199808070002  1998      8    7         104     Kenya
# 68072   199808070003  1998      8    7         203  Tanzania
# 69876   200001030010  2000      1    3         228     Yemen
# ...              ...   ...    ...  ...         ...       ...
# 85923   200803110011  2008      3   11         153  Pakistan
# 85944   200803150001  2008      3   15         153  Pakistan
# 87834   200807090016  2008      7    9         209    Turkey
# 95008   201001190011  2010      1    0         153  Pakistan
# 102708  201108130011  2011      8   13         153  Pakistan
#
#                             Region                        State  \
# 54691   Middle East & North Africa                         Adan
# 54692   Middle East & North Africa                         Adan
# ...

# %%
Al_Qaida[Al_Qaida['Killed']>20]
# Out:
#            Event_id  Year  Month  Day  Country_id         Country  \
# 68071  199808070002  1998      8    7         104           Kenya
# 73126  200109110004  2001      9   11         217   United States
# 73127  200109110005  2001      9   11         217   United States
# 73128  200109110006  2001      9   11         217   United States
# 73129  200109110007  2001      9   11         217   United States
# 73959  200204110003  2002      4   11         208         Tunisia
# 76324  200403110001  2004      3   11         185           Spain
# 76326  200403110003  2004      3   11         185           Spain
# 76330  200403110007  2004      3   11         185           Spain
# 78219  200506010001  2005      6    1           4     Afghanistan
# 78432  200507070002  2005      7    7         603  United Kingdom
# 83837  200707140001  2007      7   14         153        Pakistan
# 85923  200803110011  2008      3   11         153        Pakistan
#
# ...

# %% [markdown]
# Al_Qaida Most mischievous gang in early 20's and have done most number kill till date and the weapon used for killing is only two
# Explosives and vehicle-borne explosive
# so if we control on the illegal tranportation of weapons then we can reduse
# we can see that in only one year (2001) there were 2 attacks on the same day so we can in same country
# so we can say that there might me some disput between USA and Al_Qaida

# %%
from ipywidgets import interact, interact_manual
@interact

def attack_year(year=list(data_gta["Year"].unique())):
    a=data_gta[data_gta["Year"]==year]
    return sns.countplot(y=a["Region"], palette="viridis")
# Out:
# interactive(children=(Dropdown(description='year', options=(1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 19…

# %%
corrMatrix = data_gta.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
df=data_gta.Group_name.value_counts(normalize=True,ascending=False)
df.head(10).plot.pie(autopct="%.1f%%",figsize=(10,8))
plt.show()

# %%
data_gta.Targeted_area.value_counts(normalize=True).plot(kind='barh',color='crimson')
plt.show()

# %%
plt.figure(figsize=(9, 8))
sns.distplot(data_gta['Year'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(9, 8))
sns.histplot(data_gta['Year'])

# %%
from wordcloud import WordCloud
from scipy import signal
cities = data_gta.State.dropna(False)
plt.subplots(figsize=(10,10))
wordcloud = WordCloud(background_color = 'white',
                     width = 512,
                     height = 384).generate(' '.join(cities))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of Series.dropna will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
max_killevery_gname=[]
year=[]
g_name=[]
for i in data_gta:
  if i=='Year':
    for j in range(2004,2018):
      year.append(j)
      attack=data_gta[data_gta['Year']==j]
      max_killevery_gname.append(attack.Group_name.value_counts()[1])
      g_name.append(attack.Group_name.value_counts()[1:2].keys())
most_kill = pd.DataFrame({'Year' : year,
                                'Group_name' : g_name,
                                'Number of Attacks' : max_killevery_gname })
most_kill['Group_name']=most_kill['Group_name'].apply(lambda x: x[0] )
plt.figure(figsize=(15,10))
plt.xlabel('Year')
plt.ylabel('Number of Attack')
plt.title('Every year which gang was most active in recent years')
plt.plot(most_kill['Year'],most_kill['Number of Attacks'])
for i in range(len(most_kill['Year'])):
        plt.text(most_kill['Year'][i],most_kill['Number of Attacks'][i],most_kill['Group_name'][i][0:9],rotation=60,fontsize=15)

# %%
g_name=['Taliban','Communist Party of India - Maoist (CPI-Maoist)','Islamic State of Iraq and the Levant (ISIL)']
for i in g_name:
  print(i,':: '+data_gta[data_gta['Group_name']==i]['Type_of_attack'].value_counts().idxmax())
# Out:
# Taliban :: Bombing/Explosion
# Communist Party of India - Maoist (CPI-Maoist) :: Armed Assault
# Islamic State of Iraq and the Levant (ISIL) :: Bombing/Explosion

# %% [markdown]
# Top 11 Most Attacked Country

# %%
most_number_of_attack=pd.DataFrame(data_gta['Country'].value_counts())
most_number_of_attack=most_number_of_attack.reset_index()
most_number_of_attack=most_number_of_attack.rename(columns={'index':'country','Country':'number_of_kill'})
most_number_of_attack
# Out:
#                country  number_of_kill
# 0                 Iraq           21510
# 1             Pakistan           12756
# 2          Afghanistan           10871
# 3                India           10491
# 4             Colombia            6865
# ..                 ...             ...
# 197  Wallis and Futuna               1
# 198        South Yemen               1
# 199       Vatican City               1
# 200      South Vietnam               1
# 201        North Korea               1
#
# [202 rows x 2 columns]

# %%
TOP_11_MOST_ATTCKED_COUNTRY=most_number_of_attack[most_number_of_attack['number_of_kill']>3000]
TOP_11_MOST_ATTCKED_COUNTRY
# Out:
#            country  number_of_kill
# 0             Iraq           21510
# 1         Pakistan           12756
# 2      Afghanistan           10871
# 3            India           10491
# 4         Colombia            6865
# 5      Philippines            5843
# 6             Peru            4916
# 7           Turkey            3767
# 8      El Salvador            3369
# 9         Thailand            3346
# 10  United Kingdom            3212

# %%
plt.figure(figsize=(15,5))
plt.barh(TOP_11_MOST_ATTCKED_COUNTRY.country,TOP_11_MOST_ATTCKED_COUNTRY.number_of_kill)
# Out:
# <BarContainer object of 11 artists>

# %% [markdown]
# So 11 country are most dangrous place to live bacause they are having most attacks

# %%
Taliban=data_gta[data_gta['Group_name']=='Taliban']
Taliban_number_attack=Taliban['Country'].count()
Taliban_number_kill=Taliban['Killed'].sum()
CPI=data_gta[data_gta['Group_name']=='Communist Party of India - Maoist (CPI-Maoist)']
CPI_number_attack=CPI['Country'].count()
CPI_number_kill=CPI['Killed'].sum()
ISIL=data_gta[data_gta['Group_name']=='Islamic State of Iraq and the Levant (ISIL)']
ISIL_number_attack=ISIL['Country'].count()
ISIL_number_kill=ISIL['Killed'].sum()
name_of_gang=['Taliban','CPI','ISIL']
plt.figure(figsize=(20,10))
x_nu_attack=[Taliban_number_attack,CPI_number_attack,ISIL_number_attack]
y_nu_kill=[Taliban_number_kill,CPI_number_kill,ISIL_number_kill]
plt.plot(x_nu_attack,y_nu_kill,'Dr')
plt.grid()
plt.title('KILL VS ATTACKS')
plt.xlabel('NUMBER OF ATTACKS')
plt.ylabel('NUMBER OF KILL')
for i in range(len(x_nu_attack)):
        plt.text(x_nu_attack[i],y_nu_kill[i],name_of_gang[i],fontsize=15)
# so we can write here out three active gang from last 20 year ISIL is the most attacks and killed org.
